# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open("20221003001_trainDataFileList.pickle", "rb") as f:
    train_list = pickle.load(f)

# %%
train_list
# Out:
#       filename cls                                           file_pth
# 0    00074.mp4   0  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 1    00121.mp4   0  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 2    00126.mp4   0  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 3    00230.mp4   0  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 4    00262.mp4   0  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# ..         ...  ..                                                ...
# 789  29855.mp4   9  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 790  29938.mp4   9  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 791  29971.mp4   9  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 792  29978.mp4   9  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
# 793  29999.mp4   9  /home/azetry/Projects/CCBDA_2022_HW1/data/trai...
#
# [30000 rows x 3 columns]

# %%
plt.figure(figsize=(15,16))
sns.countplot(x='cls', data=train_list)
# Out:
# <AxesSubplot: xlabel='cls', ylabel='count'>
